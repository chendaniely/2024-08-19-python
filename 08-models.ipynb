# %%
import pandas as pd
import seaborn as sns
from sklearn import linear_model
# from sklearn.linear_model import LinearRegression
import statsmodels.formula.api as smf

# %%
tips = sns.load_dataset("tips")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
model = smf.ols("tip ~ total_bill", data=tips)

# %%
results = model.fit()

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    tip   R-squared:                       0.457
# Model:                            OLS   Adj. R-squared:                  0.454
# Method:                 Least Squares   F-statistic:                     203.4
# Date:                Tue, 20 Aug 2024   Prob (F-statistic):           6.69e-34
# Time:                        07:01:43   Log-Likelihood:                -350.54
# No. Observations:                 244   AIC:                             705.1
# Df Residuals:                     242   BIC:                             712.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.9203      0.160      5.761      0.000       0.606       1.235
# total_bill     0.1050      0.007     14.260      0.000       0.091       0.120
# ==============================================================================
# Omnibus:                       20.185   Durbin-Watson:                   2.151
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               37.750
# Skew:                           0.443   Prob(JB):                     6.35e-09
# Kurtosis:                       4.711   Cond. No.                         53.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model = smf.ols("tip ~ total_bill + sex + smoker + day + size", data=tips)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    tip   R-squared:                       0.470
# Model:                            OLS   Adj. R-squared:                  0.454
# Method:                 Least Squares   F-statistic:                     29.90
# Date:                Tue, 20 Aug 2024   Prob (F-statistic):           2.12e-29
# Time:                        07:04:38   Log-Likelihood:                -347.49
# No. Observations:                 244   AIC:                             711.0
# Df Residuals:                     236   BIC:                             739.0
# Df Model:                           7
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         0.5917      0.255      2.318      0.021       0.089       1.095
# sex[T.Female]     0.0324      0.141      0.230      0.819      -0.246       0.311
# smoker[T.No]      0.0849      0.146      0.581      0.561      -0.203       0.372
# day[T.Fri]        0.1198      0.279      0.430      0.668      -0.429       0.669
# day[T.Sat]       -0.0261      0.175     -0.149      0.882      -0.371       0.319
# day[T.Sun]        0.0701      0.181      0.386      0.700      -0.287       0.428
# total_bill        0.0943      0.010      9.922      0.000       0.076       0.113
# size              0.1770      0.089      1.987      0.048       0.001       0.353
# ==============================================================================
# Omnibus:                       27.933   Durbin-Watson:                   2.095
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               52.677
# Skew:                           0.608   Prob(JB):                     3.64e-12
# Kurtosis:                       4.924   Cond. No.                         117.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
lr = linear_model.LinearRegression()

# %%
lr.fit(X=tips["total_bill"], y=tips["tip"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 lr.fit(X=tips["total_bill"], y=tips["tip"])
#
# File ~/.pyenv/versions/3.12.3/envs/ds/lib/python3.12/site-packages/sklearn/base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File ~/.pyenv/versions/3.12.3/envs/ds/lib/python3.12/site-packages/sklearn/linear_model/_base.py:609, in LinearRegression.fit(self, X, y, sample_weight)
#     605 n_jobs_ = self.n_jobs
#     607 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 609 X, y = self._validate_data(
#     610     X,
#     611     y,
#     612     accept_sparse=accept_sparse,
#     613     y_numeric=True,
#     614     multi_output=True,
#     615     force_writeable=True,
#     616 )
#     618 has_sw = sample_weight is not None
#     619 if has_sw:
#
# File ~/.pyenv/versions/3.12.3/envs/ds/lib/python3.12/site-packages/sklearn/base.py:650, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     648         y = check_array(y, input_name="y", **check_y_params)
#     649     else:
# --> 650         X, y = check_X_y(X, y, **check_params)
#     651     out = X, y
#     653 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~/.pyenv/versions/3.12.3/envs/ds/lib/python3.12/site-packages/sklearn/utils/validation.py:1301, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1296         estimator_name = _check_estimator_name(estimator)
#    1297     raise ValueError(
#    1298         f"{estimator_name} requires y to be passed, but the target y is None"
#    1299     )
# -> 1301 X = check_array(
#    1302     X,
#    1303     accept_sparse=accept_sparse,
#    1304     accept_large_sparse=accept_large_sparse,
#    1305     dtype=dtype,
#    1306     order=order,
#    1307     copy=copy,
#    1308     force_writeable=force_writeable,
#    1309     force_all_finite=force_all_finite,
#    1310     ensure_2d=ensure_2d,
#    1311     allow_nd=allow_nd,
#    1312     ensure_min_samples=ensure_min_samples,
#    1313     ensure_min_features=ensure_min_features,
#    1314     estimator=estimator,
#    1315     input_name="X",
#    1316 )
#    1318 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1320 check_consistent_length(X, y)
#
# File ~/.pyenv/versions/3.12.3/envs/ds/lib/python3.12/site-packages/sklearn/utils/validation.py:1050, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1043         else:
#    1044             msg = (
#    1045                 f"Expected 2D array, got 1D array instead:\narray={array}.\n"
#    1046                 "Reshape your data either using array.reshape(-1, 1) if "
#    1047                 "your data has a single feature or array.reshape(1, -1) "
#    1048                 "if it contains a single sample."
#    1049             )
# -> 1050         raise ValueError(msg)
#    1052 if dtype_numeric and hasattr(array.dtype, "kind") and array.dtype.kind in "USV":
#    1053     raise ValueError(
#    1054         "dtype='numeric' is not compatible with arrays of bytes/strings."
#    1055         "Convert your data to numeric values explicitly instead."
#    1056     )
#
# ValueError: Expected a 2-dimensional container but got <class 'pandas.core.series.Series'> instead. Pass a DataFrame containing a single row (i.e. single sample) or a single column (i.e. single feature) instead.

# %%
results = lr.fit(X=tips[["total_bill"]], y=tips["tip"])
results
# Out:
# LinearRegression()

# %%
results.coef_
# Out:
# array([0.10502452])

# %%
results.intercept_
# Out:
# np.float64(0.9202696135546744)

# %%
lr = linear_model.LinearRegression()
results = lr.fit(X=tips[["total_bill"]], y=tips["tip"])
results
# Out:
# LinearRegression()

# %%
lr = linear_model.LinearRegression()
results = lr.fit(X=tips[["total_bill", "size", "smoker"]], y=tips["tip"])
results
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 2
#       1 lr = linear_model.LinearRegression()
# ----> 2 results = lr.fit(X=tips[["total_bill", "size", "smoker"]], y=tips["tip"])
#       3 results
#
# File ~/.pyenv/versions/3.12.3/envs/ds/lib/python3.12/site-packages/sklearn/base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File ~/.pyenv/versions/3.12.3/envs/ds/lib/python3.12/site-packages/sklearn/linear_model/_base.py:629, in LinearRegression.fit(self, X, y, sample_weight)
#     624 # Note that neither _rescale_data nor the rest of the fit method of
#     625 # LinearRegression can benefit from in-place operations when X is a
#     626 # sparse matrix. Therefore, let's not copy X when it is sparse.
#     627 copy_X_in_preprocess_data = self.copy_X and not sp.issparse(X)
# --> 629 X, y, X_offset, y_offset, X_scale = _preprocess_data(
#     630     X,
#     631     y,
#     632     fit_intercept=self.fit_intercept,
#     633     copy=copy_X_in_preprocess_data,
#     634     sample_weight=sample_weight,
#     635 )
#     637 if has_sw:
#     638     # Sample weight can be implemented via a simple rescaling. Note
#     639     # that we safely do inplace rescaling when _preprocess_data has
#     640     # already made a copy if requested.
#     641     X, y, sample_weight_sqrt = _rescale_data(
#     642         X, y, sample_weight, inplace=copy_X_in_preprocess_data
#     643     )
#
# File ~/.pyenv/versions/3.12.3/envs/ds/lib/python3.12/site-packages/sklearn/linear_model/_base.py:175, in _preprocess_data(X, y, fit_intercept, copy, copy_y, sample_weight, check_input)
#     172     sample_weight = xp.asarray(sample_weight)
#     174 if check_input:
# --> 175     X = check_array(
#     176         X, copy=copy, accept_sparse=["csr", "csc"], dtype=supported_float_dtypes(xp)
#     177     )
#     178     y = check_array(y, dtype=X.dtype, copy=copy_y, ensure_2d=False)
#     179 else:
#
# File ~/.pyenv/versions/3.12.3/envs/ds/lib/python3.12/site-packages/sklearn/utils/validation.py:1012, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1010         array = xp.astype(array, dtype, copy=False)
#    1011     else:
# -> 1012         array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#    1013 except ComplexWarning as complex_warning:
#    1014     raise ValueError(
#    1015         "Complex data not supported\n{}\n".format(array)
#    1016     ) from complex_warning
#
# File ~/.pyenv/versions/3.12.3/envs/ds/lib/python3.12/site-packages/sklearn/utils/_array_api.py:751, in _asarray_with_order(array, dtype, order, copy, xp, device)
#     749     array = numpy.array(array, order=order, dtype=dtype)
#     750 else:
# --> 751     array = numpy.asarray(array, order=order, dtype=dtype)
#     753 # At this point array is a NumPy ndarray. We convert it to an array
#     754 # container that is consistent with the input's namespace.
#     755 return xp.asarray(array)
#
# ValueError: could not convert string to float: 'No'

# %%
# dummy variable encoding
# one-hot encoding

# %%
tips_subset = tips[["total_bill", "tip", "size", "smoker"]]
tips_subset
# Out:
#      total_bill   tip  size smoker
# 0         16.99  1.01     2     No
# 1         10.34  1.66     3     No
# 2         21.01  3.50     3     No
# 3         23.68  3.31     2     No
# 4         24.59  3.61     4     No
# ..          ...   ...   ...    ...
# 239       29.03  5.92     3     No
# 240       27.18  2.00     2    Yes
# 241       22.67  2.00     2    Yes
# 242       17.82  1.75     2     No
# 243       18.78  3.00     2     No
#
# [244 rows x 4 columns]

# %%
pd.get_dummies(tips_subset)
# Out:
#      total_bill   tip  size  smoker_Yes  smoker_No
# 0         16.99  1.01     2       False       True
# 1         10.34  1.66     3       False       True
# 2         21.01  3.50     3       False       True
# 3         23.68  3.31     2       False       True
# 4         24.59  3.61     4       False       True
# ..          ...   ...   ...         ...        ...
# 239       29.03  5.92     3       False       True
# 240       27.18  2.00     2        True      False
# 241       22.67  2.00     2        True      False
# 242       17.82  1.75     2       False       True
# 243       18.78  3.00     2       False       True
#
# [244 rows x 5 columns]

# %%
tips_dummy = pd.get_dummies(tips_subset, drop_first=True)
tips_dummy
# Out:
#      total_bill   tip  size  smoker_No
# 0         16.99  1.01     2       True
# 1         10.34  1.66     3       True
# 2         21.01  3.50     3       True
# 3         23.68  3.31     2       True
# 4         24.59  3.61     4       True
# ..          ...   ...   ...        ...
# 239       29.03  5.92     3       True
# 240       27.18  2.00     2      False
# 241       22.67  2.00     2      False
# 242       17.82  1.75     2       True
# 243       18.78  3.00     2       True
#
# [244 rows x 4 columns]

# %%
y = tips_dummy.pop("tip")

# %%
y
# Out:
# 0      1.01
# 1      1.66
# 2      3.50
# 3      3.31
# 4      3.61
#        ...
# 239    5.92
# 240    2.00
# 241    2.00
# 242    1.75
# 243    3.00
# Name: tip, Length: 244, dtype: float64

# %%
tips_dummy
# Out:
#      total_bill  size  smoker_No
# 0         16.99     2       True
# 1         10.34     3       True
# 2         21.01     3       True
# 3         23.68     2       True
# 4         24.59     4       True
# ..          ...   ...        ...
# 239       29.03     3       True
# 240       27.18     2      False
# 241       22.67     2      False
# 242       17.82     2       True
# 243       18.78     2       True
#
# [244 rows x 3 columns]

# %%
lr = linear_model.LinearRegression()
results = lr.fit(X=tips_dummy, y=y)

# %%
results
# Out:
# LinearRegression()

# %%
results.coef_
# Out:
# array([0.09388839, 0.18033156, 0.08343255])

# %%
results.intercept_
# Out:
# np.float64(0.6255829641796269)

# %%
tips_dummy.columns
# Out:
# Index(['total_bill', 'size', 'smoker_No'], dtype='object')

# %%
results.coef_
# Out:
# array([0.09388839, 0.18033156, 0.08343255])
