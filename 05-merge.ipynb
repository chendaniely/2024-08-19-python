# %%
import pandas as pd

# %%
person = pd.read_csv('data/survey_person.csv')
site = pd.read_csv('data/survey_site.csv')
survey = pd.read_csv('data/survey_survey.csv')
visited = pd.read_csv('data/survey_visited.csv')

# %%
person
# Out:
#       ident   personal    family
# 0      dyer    William      Dyer
# 1        pb      Frank   Pabodie
# 2      lake   Anderson      Lake
# 3       roe  Valentina   Roerich
# 4  danforth      Frank  Danforth

# %%
site
# Out:
#     name    lat    long
# 0   DR-1 -49.85 -128.57
# 1   DR-3 -47.15 -126.72
# 2  MSK-4 -48.87 -123.40

# %%
survey
# Out:
#     taken person quant  reading
# 0     619   dyer   rad     9.82
# 1     619   dyer   sal     0.13
# 2     622   dyer   rad     7.80
# 3     622   dyer   sal     0.09
# 4     734     pb   rad     8.41
# 5     734   lake   sal     0.05
# 6     734     pb  temp   -21.50
# 7     735     pb   rad     7.22
# 8     735    NaN   sal     0.06
# 9     735    NaN  temp   -26.00
# 10    751     pb   rad     4.35
# 11    751     pb  temp   -18.50
# 12    751   lake   sal     0.10
# 13    752   lake   rad     2.19
# 14    752   lake   sal     0.09
# 15    752   lake  temp   -16.00
# 16    752    roe   sal    41.60
# 17    837   lake   rad     1.46
# 18    837   lake   sal     0.21
# 19    837    roe   sal    22.50
# 20    844    roe   rad    11.25

# %%
visited
# Out:
#    ident   site       dated
# 0    619   DR-1  1927-02-08
# 1    622   DR-1  1927-02-10
# 2    734   DR-3  1939-01-07
# 3    735   DR-3  1930-01-12
# 4    751   DR-3  1930-02-26
# 5    752   DR-3         NaN
# 6    837  MSK-4  1932-01-14
# 7    844   DR-1  1932-03-22

# %%
visited_sub = visited.loc[[0, 2, 6]]
visited_sub
# Out:
#    ident   site       dated
# 0    619   DR-1  1927-02-08
# 2    734   DR-3  1939-01-07
# 6    837  MSK-4  1932-01-14

# %%
site
# Out:
#     name    lat    long
# 0   DR-1 -49.85 -128.57
# 1   DR-3 -47.15 -126.72
# 2  MSK-4 -48.87 -123.40

# %%
o2o = site.merge(visited_sub, left_on=["name"], right_on="site")
o2o
# Out:
#     name    lat    long  ident   site       dated
# 0   DR-1 -49.85 -128.57    619   DR-1  1927-02-08
# 1   DR-3 -47.15 -126.72    734   DR-3  1939-01-07
# 2  MSK-4 -48.87 -123.40    837  MSK-4  1932-01-14

# %%
site.shape[0]
# Out:
# 3

# %%
visited_sub.shape[0]
# Out:
# 3

# %%
o2o.shape[0]
# Out:
# 3

# %%
o2o = site.merge(
    visited_sub,
    left_on=["name"],
    right_on="site"
)
o2o
# Out:
#     name    lat    long  ident   site       dated
# 0   DR-1 -49.85 -128.57    619   DR-1  1927-02-08
# 1   DR-3 -47.15 -126.72    734   DR-3  1939-01-07
# 2  MSK-4 -48.87 -123.40    837  MSK-4  1932-01-14

# %%
o2o = site.merge(
    visited_sub,
    left_on=["name"],
    right_on="site",
    validate="1:1"
)
o2o
# Out:
#     name    lat    long  ident   site       dated
# 0   DR-1 -49.85 -128.57    619   DR-1  1927-02-08
# 1   DR-3 -47.15 -126.72    734   DR-3  1939-01-07
# 2  MSK-4 -48.87 -123.40    837  MSK-4  1932-01-14

# %%
o2m = site.merge(
    visited,
    left_on="name",
    right_on="site",
    validate="1:m"
)
o2m
# Out:
#     name    lat    long  ident   site       dated
# 0   DR-1 -49.85 -128.57    619   DR-1  1927-02-08
# 1   DR-1 -49.85 -128.57    622   DR-1  1927-02-10
# 2   DR-1 -49.85 -128.57    844   DR-1  1932-03-22
# 3   DR-3 -47.15 -126.72    734   DR-3  1939-01-07
# 4   DR-3 -47.15 -126.72    735   DR-3  1930-01-12
# 5   DR-3 -47.15 -126.72    751   DR-3  1930-02-26
# 6   DR-3 -47.15 -126.72    752   DR-3         NaN
# 7  MSK-4 -48.87 -123.40    837  MSK-4  1932-01-14

# %%
visited.shape[0]
# Out:
# 8

# %%
o2m.shape[0]
# Out:
# 8

# %%
8 == 8
# Out:
# True

# %%
assert 8 == 8

# %%
assert 8 == 7
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 assert 8 == 7
#
# AssertionError:

# %%
assert visited.shape[0] == o2m.shape[0]

# %%
df1 = pd.DataFrame({
    'a': ['a1', 'a2', 'a3', 'a4', 'a5'],
    'b': [1, 1, 2, 2, 3]
})
df1
# Out:
#     a  b
# 0  a1  1
# 1  a2  1
# 2  a3  2
# 3  a4  2
# 4  a5  3

# %%
df2 = pd.DataFrame({
    'a2': ['2a1', '2a2', '2a3', '2a4', '2a5'],
    'b2': [1, 1, 1, 2, 2]
})
df2
# Out:
#     a2  b2
# 0  2a1   1
# 1  2a2   1
# 2  2a3   1
# 3  2a4   2
# 4  2a5   2

# %%
m2m = df1.merge(df2, left_on="b", right_on="b2", validate="m:m")
m2m
# Out:
#     a  b   a2  b2
# 0  a1  1  2a1   1
# 1  a1  1  2a2   1
# 2  a1  1  2a3   1
# 3  a2  1  2a1   1
# 4  a2  1  2a2   1
# 5  a2  1  2a3   1
# 6  a3  2  2a4   2
# 7  a3  2  2a5   2
# 8  a4  2  2a4   2
# 9  a4  2  2a5   2

# %%
df1.merge(df2, left_on="b", right_on="b2", how="left", validate="m:m")
# Out:
#      a  b   a2   b2
# 0   a1  1  2a1  1.0
# 1   a1  1  2a2  1.0
# 2   a1  1  2a3  1.0
# 3   a2  1  2a1  1.0
# 4   a2  1  2a2  1.0
# 5   a2  1  2a3  1.0
# 6   a3  2  2a4  2.0
# 7   a3  2  2a5  2.0
# 8   a4  2  2a4  2.0
# 9   a4  2  2a5  2.0
# 10  a5  3  NaN  NaN

# %%
m2m.shape[0] <= df2.shape[0]
# Out:
# False
