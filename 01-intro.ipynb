# %%
import pandas

# %%
pandas.read_csv("data/gapminder.tsv", sep="\t")
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
df = pandas.read_csv("data/gapminder.tsv", sep="\t")

# %%
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
df.sample(5)
# Out:
#               country continent  year  lifeExp       pop     gdpPercap
# 157          Botswana    Africa  1957   49.618    474639    918.232535
# 1377  Slovak Republic    Europe  1997   72.710   5383010  12126.230650
# 726              Iran      Asia  1982   59.620  43072751   7608.334602
# 95            Bahrain      Asia  2007   75.635    708573  29796.048340
# 217          Cambodia      Asia  1957   41.366   5322536    434.038336

# %%
import pandas as pd

# %%
df = pd.read_csv("data/gapminder.tsv", sep="\t")

# %%
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
df.tail()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 1699  Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700  Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701  Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702  Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703  Zimbabwe    Africa  2007   43.487  12311143  469.709298

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (1704, 6)

# %%
df.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df.shape()
#
# TypeError: 'tuple' object is not callable

# %%
(1704, 6)()
# Out:
# <>:1: SyntaxWarning: 'tuple' object is not callable; perhaps you missed a comma?
# <>:1: SyntaxWarning: 'tuple' object is not callable; perhaps you missed a comma?
# /var/folders/2b/qckmp39n7qn1dh0tpcm8g89w0000gn/T/ipykernel_74868/4140916200.py:1: SyntaxWarning: 'tuple' object is not callable; perhaps you missed a comma?
#   (1704, 6)()
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 (1704, 6)()
#
# TypeError: 'tuple' object is not callable

# %%
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
df.columns
# Out:
# Index(['country', 'continent', 'year', 'lifeExp', 'pop', 'gdpPercap'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1704, step=1)

# %%
df.values
# Out:
# array([['Afghanistan', 'Asia', 1952, 28.801, 8425333, 779.4453145],
#        ['Afghanistan', 'Asia', 1957, 30.332, 9240934, 820.8530296],
#        ['Afghanistan', 'Asia', 1962, 31.997, 10267083, 853.10071],
#        ...,
#        ['Zimbabwe', 'Africa', 1997, 46.809, 11404948, 792.4499603],
#        ['Zimbabwe', 'Africa', 2002, 39.989, 11926563, 672.0386227],
#        ['Zimbabwe', 'Africa', 2007, 43.487, 12311143, 469.7092981]],
#       dtype=object)

# %%
df.dtypes
# Out:
# country       object
# continent     object
# year           int64
# lifeExp      float64
# pop            int64
# gdpPercap    float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   continent  1704 non-null   object
#  2   year       1704 non-null   int64
#  3   lifeExp    1704 non-null   float64
#  4   pop        1704 non-null   int64
#  5   gdpPercap  1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %%
df["country"]
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
country_df = df["country"]
country_df
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
type(country_df)
# Out:
# pandas.core.series.Series

# %%
country_df = df[["country"]]
country_df
# Out:
#           country
# 0     Afghanistan
# 1     Afghanistan
# 2     Afghanistan
# 3     Afghanistan
# 4     Afghanistan
# ...           ...
# 1699     Zimbabwe
# 1700     Zimbabwe
# 1701     Zimbabwe
# 1702     Zimbabwe
# 1703     Zimbabwe
#
# [1704 rows x 1 columns]

# %%
type(country_df)
# Out:
# pandas.core.frame.DataFrame

# %%
subset = df[["country", "continent", "year"]]

# %%
subset.head()
# Out:
#        country continent  year
# 0  Afghanistan      Asia  1952
# 1  Afghanistan      Asia  1957
# 2  Afghanistan      Asia  1962
# 3  Afghanistan      Asia  1967
# 4  Afghanistan      Asia  1972

# %%
subset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   continent  1704 non-null   object
#  2   year       1704 non-null   int64
# dtypes: int64(1), object(2)
# memory usage: 40.1+ KB

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
df.loc[0]
# Out:
# country      Afghanistan
# continent           Asia
# year                1952
# lifeExp           28.801
# pop              8425333
# gdpPercap     779.445314
# Name: 0, dtype: object

# %%
type(df.loc[0])
# Out:
# pandas.core.series.Series

# %%
df.loc[[0]]
# Out:
#        country continent  year  lifeExp      pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801  8425333  779.445314

# %%
df.loc[-1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/.pyenv/versions/3.12.3/envs/ds/lib/python3.12/site-packages/pandas/core/indexes/range.py:413, in RangeIndex.get_loc(self, key)
#     412 try:
# --> 413     return self._range.index(new_key)
#     414 except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 df.loc[-1]
#
# File ~/.pyenv/versions/3.12.3/envs/ds/lib/python3.12/site-packages/pandas/core/indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/.pyenv/versions/3.12.3/envs/ds/lib/python3.12/site-packages/pandas/core/indexing.py:1431, in _LocIndexer._getitem_axis(self, key, axis)
#    1429 # fall thru to straight lookup
#    1430 self._validate_key(key, axis)
# -> 1431 return self._get_label(key, axis=axis)
#
# File ~/.pyenv/versions/3.12.3/envs/ds/lib/python3.12/site-packages/pandas/core/indexing.py:1381, in _LocIndexer._get_label(self, label, axis)
#    1379 def _get_label(self, label, axis: AxisInt):
#    1380     # GH#5567 this will fail if the label is not present in the axis.
# -> 1381     return self.obj.xs(label, axis=axis)
#
# File ~/.pyenv/versions/3.12.3/envs/ds/lib/python3.12/site-packages/pandas/core/generic.py:4301, in NDFrame.xs(self, key, axis, level, drop_level)
#    4299             new_index = index[loc]
#    4300 else:
# -> 4301     loc = index.get_loc(key)
#    4303     if isinstance(loc, np.ndarray):
#    4304         if loc.dtype == np.bool_:
#
# File ~/.pyenv/versions/3.12.3/envs/ds/lib/python3.12/site-packages/pandas/core/indexes/range.py:415, in RangeIndex.get_loc(self, key)
#     413         return self._range.index(new_key)
#     414     except ValueError as err:
# --> 415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
#     417     raise KeyError(key)
#
# KeyError: -1

# %%
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
df.iloc[0]
# Out:
# country      Afghanistan
# continent           Asia
# year                1952
# lifeExp           28.801
# pop              8425333
# gdpPercap     779.445314
# Name: 0, dtype: object

# %%
df.iloc[-1]
# Out:
# country        Zimbabwe
# continent        Africa
# year               2007
# lifeExp          43.487
# pop            12311143
# gdpPercap    469.709298
# Name: 1703, dtype: object

# %%
df.iloc[[0, -1]]
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298

# %%
subset = df.loc[[0, 1, 2, 1703], ["year", "pop"]]

# %%
subset
# Out:
#       year       pop
# 0     1952   8425333
# 1     1957   9240934
# 2     1962  10267083
# 1703  2007  12311143

# %%
subset.loc[1703]
# Out:
# year        2007
# pop     12311143
# Name: 1703, dtype: int64

# %%
subset.iloc[-1]
# Out:
# year        2007
# pop     12311143
# Name: 1703, dtype: int64

# %%
df.iloc[[0, 1, 2, 1703], [2, 4]]
# Out:
#       year       pop
# 0     1952   8425333
# 1     1957   9240934
# 2     1962  10267083
# 1703  2007  12311143

# %%
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
df.groupby("year")["lifeExp"].mean()
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %%
df["lifeExp"].mean()
# Out:
# np.float64(59.474439366197174)

# %%
df.groupby(["year"])[["lifeExp"]].mean()
# Out:
#         lifeExp
# year
# 1952  49.057620
# 1957  51.507401
# 1962  53.609249
# 1967  55.678290
# 1972  57.647386
# 1977  59.570157
# 1982  61.533197
# 1987  63.212613
# 1992  64.160338
# 1997  65.014676
# 2002  65.694923
# 2007  67.007423

# %%
grouped = df.groupby(["year", "continent"])[["lifeExp", "gdpPercap"]].mean()

# %%
grouped
# Out:
#                   lifeExp     gdpPercap
# year continent
# 1952 Africa     39.135500   1252.572466
#      Americas   53.279840   4079.062552
#      Asia       46.314394   5195.484004
#      Europe     64.408500   5661.057435
#      Oceania    69.255000  10298.085650
# 1957 Africa     41.266346   1385.236062
#      Americas   55.960280   4616.043733
#      Asia       49.318544   5787.732940
#      Europe     66.703067   6963.012816
#      Oceania    70.295000  11598.522455
# 1962 Africa     43.319442   1598.078825
#      Americas   58.398760   4901.541870
#      Asia       51.563223   5729.369625
#      Europe     68.539233   8365.486814
#      Oceania    71.085000  12696.452430
# 1967 Africa     45.334538   2050.363801
#      Americas   60.410920   5668.253496
#      Asia       54.663640   5971.173374
#      Europe     69.737600  10143.823757
#      Oceania    71.310000  14495.021790
# 1972 Africa     47.450942   2339.615674
#      Americas   62.394920   6491.334139
#      Asia       57.319269   8187.468699
#      Europe     70.775033  12479.575246
#      Oceania    71.910000  16417.333380
# 1977 Africa     49.580423   2585.938508
#      Americas   64.391560   7352.007126
#      Asia       59.610556   7791.314020
#      Europe     71.937767  14283.979110
#      Oceania    72.855000  17283.957605
# 1982 Africa     51.592865   2481.592960
#      Americas   66.228840   7506.737088
#      Asia       62.617939   7434.135157
#      Europe     72.806400  15617.896551
#      Oceania    74.290000  18554.709840
# 1987 Africa     53.344788   2282.668991
#      Americas   68.090720   7793.400261
#      Asia       64.851182   7608.226508
#      Europe     73.642167  17214.310727
#      Oceania    75.320000  20448.040160
# 1992 Africa     53.629577   2281.810333
#      Americas   69.568360   8044.934406
#      Asia       66.537212   8639.690248
#      Europe     74.440100  17061.568084
#      Oceania    76.945000  20894.045885
# 1997 Africa     53.598269   2378.759555
#      Americas   71.150480   8889.300863
#      Asia       68.020515   9834.093295
#      Europe     75.505167  19076.781802
#      Oceania    78.190000  24024.175170
# 2002 Africa     53.325231   2599.385159
#      Americas   72.422040   9287.677107
#      Asia       69.233879  10174.090397
#      Europe     76.700600  21711.732422
#      Oceania    79.740000  26938.778040
# 2007 Africa     54.806038   3089.032605
#      Americas   73.608120  11003.031625
#      Asia       70.728485  12473.026870
#      Europe     77.648600  25054.481636
#      Oceania    80.719500  29810.188275

# %%
type(grouped)
# Out:
# pandas.core.frame.DataFrame

# %%
grouped.columns
# Out:
# Index(['lifeExp', 'gdpPercap'], dtype='object')

# %%
grouped.index
# Out:
# MultiIndex([(1952,   'Africa'),
#             (1952, 'Americas'),
#             (1952,     'Asia'),
#             (1952,   'Europe'),
#             (1952,  'Oceania'),
#             (1957,   'Africa'),
#             (1957, 'Americas'),
#             (1957,     'Asia'),
#             (1957,   'Europe'),
#             (1957,  'Oceania'),
#             (1962,   'Africa'),
#             (1962, 'Americas'),
#             (1962,     'Asia'),
#             (1962,   'Europe'),
#             (1962,  'Oceania'),
#             (1967,   'Africa'),
#             (1967, 'Americas'),
#             (1967,     'Asia'),
#             (1967,   'Europe'),
#             (1967,  'Oceania'),
#             (1972,   'Africa'),
#             (1972, 'Americas'),
#             (1972,     'Asia'),
#             (1972,   'Europe'),
#             (1972,  'Oceania'),
#             (1977,   'Africa'),
#             (1977, 'Americas'),
#             (1977,     'Asia'),
#             (1977,   'Europe'),
#             (1977,  'Oceania'),
#             (1982,   'Africa'),
#             (1982, 'Americas'),
#             (1982,     'Asia'),
#             (1982,   'Europe'),
#             (1982,  'Oceania'),
#             (1987,   'Africa'),
#             (1987, 'Americas'),
#             (1987,     'Asia'),
#             (1987,   'Europe'),
#             (1987,  'Oceania'),
#             (1992,   'Africa'),
#             (1992, 'Americas'),
#             (1992,     'Asia'),
#             (1992,   'Europe'),
#             (1992,  'Oceania'),
#             (1997,   'Africa'),
#             (1997, 'Americas'),
#             (1997,     'Asia'),
#             (1997,   'Europe'),
#             (1997,  'Oceania'),
#             (2002,   'Africa'),
#             (2002, 'Americas'),
#             (2002,     'Asia'),
#             (2002,   'Europe'),
#             (2002,  'Oceania'),
#             (2007,   'Africa'),
#             (2007, 'Americas'),
#             (2007,     'Asia'),
#             (2007,   'Europe'),
#             (2007,  'Oceania')],
#            names=['year', 'continent'])

# %%
grouped.reset_index()
# Out:
#     year continent    lifeExp     gdpPercap
# 0   1952    Africa  39.135500   1252.572466
# 1   1952  Americas  53.279840   4079.062552
# 2   1952      Asia  46.314394   5195.484004
# 3   1952    Europe  64.408500   5661.057435
# 4   1952   Oceania  69.255000  10298.085650
# 5   1957    Africa  41.266346   1385.236062
# 6   1957  Americas  55.960280   4616.043733
# 7   1957      Asia  49.318544   5787.732940
# 8   1957    Europe  66.703067   6963.012816
# 9   1957   Oceania  70.295000  11598.522455
# 10  1962    Africa  43.319442   1598.078825
# 11  1962  Americas  58.398760   4901.541870
# 12  1962      Asia  51.563223   5729.369625
# 13  1962    Europe  68.539233   8365.486814
# 14  1962   Oceania  71.085000  12696.452430
# 15  1967    Africa  45.334538   2050.363801
# 16  1967  Americas  60.410920   5668.253496
# 17  1967      Asia  54.663640   5971.173374
# 18  1967    Europe  69.737600  10143.823757
# 19  1967   Oceania  71.310000  14495.021790
# 20  1972    Africa  47.450942   2339.615674
# 21  1972  Americas  62.394920   6491.334139
# 22  1972      Asia  57.319269   8187.468699
# 23  1972    Europe  70.775033  12479.575246
# 24  1972   Oceania  71.910000  16417.333380
# 25  1977    Africa  49.580423   2585.938508
# 26  1977  Americas  64.391560   7352.007126
# 27  1977      Asia  59.610556   7791.314020
# 28  1977    Europe  71.937767  14283.979110
# 29  1977   Oceania  72.855000  17283.957605
# 30  1982    Africa  51.592865   2481.592960
# 31  1982  Americas  66.228840   7506.737088
# 32  1982      Asia  62.617939   7434.135157
# 33  1982    Europe  72.806400  15617.896551
# 34  1982   Oceania  74.290000  18554.709840
# 35  1987    Africa  53.344788   2282.668991
# 36  1987  Americas  68.090720   7793.400261
# 37  1987      Asia  64.851182   7608.226508
# 38  1987    Europe  73.642167  17214.310727
# 39  1987   Oceania  75.320000  20448.040160
# 40  1992    Africa  53.629577   2281.810333
# 41  1992  Americas  69.568360   8044.934406
# 42  1992      Asia  66.537212   8639.690248
# 43  1992    Europe  74.440100  17061.568084
# 44  1992   Oceania  76.945000  20894.045885
# 45  1997    Africa  53.598269   2378.759555
# 46  1997  Americas  71.150480   8889.300863
# 47  1997      Asia  68.020515   9834.093295
# 48  1997    Europe  75.505167  19076.781802
# 49  1997   Oceania  78.190000  24024.175170
# 50  2002    Africa  53.325231   2599.385159
# 51  2002  Americas  72.422040   9287.677107
# 52  2002      Asia  69.233879  10174.090397
# 53  2002    Europe  76.700600  21711.732422
# 54  2002   Oceania  79.740000  26938.778040
# 55  2007    Africa  54.806038   3089.032605
# 56  2007  Americas  73.608120  11003.031625
# 57  2007      Asia  70.728485  12473.026870
# 58  2007    Europe  77.648600  25054.481636
# 59  2007   Oceania  80.719500  29810.188275
